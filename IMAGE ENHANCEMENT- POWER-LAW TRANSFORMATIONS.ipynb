# %% [markdown]
# # IMAGE ENHANCEMENT

# %% [raw]
# 1. It is the process of image manipulation to make it more suitable for specific use.
#
# 2. It provides better contrast and a more detailed image and is used to enhance medical images, images captured in remote sensing, images from satellite etc.

# %% [markdown]
# ### Image Enhancement can be done in:

# %% [markdown]
# ### 1. Spatial Domain:
# There is a direct manipulation of a pixel in an image (on the image plane)

# %% [markdown]
# ![](1.jpg)

# %% [markdown]
# ### 2. Frequency Domain:
# Processing the image is based on modifying the Fourier transform of an image.

# %% [markdown]
# ![](2.jpg)

# %% [markdown]
# # Why is it done?

# %% [raw]
# It is done for the following reasons:
#
#     1. Highlighting interesting detail in images.
#
#     2. Removing noise from images.
#
#     3. Making images more visually appealing.

# %% [raw]
# The transformation function is given as follows:
#
# S = T(r)
#
# --Where, r is the pixels of the input image. s is the pixels of the output image.
#
# --T is a transformation function that maps each value to r to each value of s.

# %% [raw]
# It can be achieved through grey level transformations.

# %% [markdown]
# # POWER-LAW TRANSFORMATIONS:

# %% [raw]
# 1. There are further two transformation is power law transformations, that include nth power and nth root transformation. The expression for power-law transformation is given as:
#
# s=c*(r**γ)
#
# where γ and c are real numbers.
#
# 2. This transformation is also known as gamma transformation. This type of transformation is used for enhancing images for a different type of display devices. The gamma of different display devices is different. For example, Gamma of CRT lies in between of 1.8 to 2.5, that means the image displayed on CRT is dark.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
im = cv2.imread('cam.jpg',0)

fig = plt.figure(figsize=(15,5))

# %%
ax = fig.add_subplot(121)
plt.title('Original',fontsize=18)
plt.imshow(im,cmap='gray')

# %%
im1 = im/255.0
im_power_law_transformation = cv2.pow(im1,1.8)

# %%
ax = fig.add_subplot(122)
plt.imshow(im_power_law_transformation,cmap='gray')
ax.set_title('Power Law Transform',fontsize=18)
# Out:
# Text(0.5, 1.0, 'Power Law Transform')

# %% [markdown]
# # All in one

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

im = cv2.imread('cam.jpg',0)

im1 = im/255.0
im_power_law_transformation = cv2.pow(im1,1.8)

fig = plt.figure(figsize=(15,5))

ax = fig.add_subplot(121)
plt.title('Original',fontsize=18)
plt.imshow(im,cmap='gray')

ax = fig.add_subplot(122)
plt.imshow(im_power_law_transformation,cmap='gray')
ax.set_title('Power Law Transform',fontsize=18)
# Out:
# Text(0.5, 1.0, 'Power Law Transform')
